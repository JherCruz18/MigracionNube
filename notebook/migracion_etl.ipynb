# %%
pip install mysql-connector-python pandas google-cloud-bigquery
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# se descarga la libreria de google cloud
pip install google-cloud
# Out:
#   Cell In[72], line 2
#     pip install google-cloud
#         ^
# SyntaxError: invalid syntax

# %%
#Se descarga la libreria de big query
pip install google-cloud-bigquery
# Out:
# ...
#
# ...

# %%
import pandas as pd
import sqlalchemy
import pymysql
import io
import socket
import os
from google.cloud import bigquery

from sqlalchemy import create_engine #SE IMPORTA EL TIPO DE SERVICIO PARA LA CONEXION

# %%
# Lectura de dim_cliente.csv

cliente = pd.read_csv("C:/Users/jcruz/OneDrive/Escritorio/migracion/csv_marketing/dim_cliente.csv")

dim_cliente_f=cliente.fillna('NA')

# %%
#Verificar los datos a migrar
print(cliente)
# Out:
#      cliente_id             nombre genero  edad              region  \
# 0             1       Allison Hill      M    23            Arequipa
# 1             2        Noah Rhodes      M    60            Chiclayo
# 2             3    Angie Henderson      F    31            Chiclayo
# 3             4      Daniel Wagner      M    59               Cusco
# 4             5    Cristian Santos      M    58            Chiclayo
# ..          ...                ...    ...   ...                 ...
# 995         996      Brittany Ward      F    59            Trujillo
# 996         997     Edward Stanley      F    28            Chiclayo
# 997         998  Christina Johnson      M    55            Trujillo
# 998         999       Edgar Miller      M    55            Chiclayo
# 999        1000  Elizabeth Sanders      F    27  Lima Metropolitana
#
#     fecha_registro
# 0       2024-04-22
# 1       2025-03-04
# 2       2024-09-03
# 3       2023-10-31
# 4       2023-06-18
# ..             ...
# ...

# %%
#Se realiza Conexion con llave publica

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r'civil-being-452701-p9-68613775f20a.json'

# %%
# Conexión a la dataset y obtención de la tabla
client = bigquery.Client(project='civil-being-452701-p9')
dataset = client.dataset('marketingdmc_db')
table_tp = dataset.table('dim_cliente')
table = client.get_table(table_tp)

# %%
#migracion de dim_cliente.csv a BigQuery

errores = client.insert_rows(table, cliente.to_dict(orient="records"))

if errores == []:
  print("Se inserto correctamente")
else:
  print("ERROR", errores)
# Out:
# Se inserto correctamente

# %%
# Conexión a la dataset y obtención de la tabla
client = bigquery.Client(project='civil-being-452701-p9')
dataset = client.dataset('marketingdmc_db')
table_tp = dataset.table('dim_campania')
table = client.get_table(table_tp)

# %%
# Lectura de dim_campania.csv

campania = pd.read_csv("C:/Users/jcruz/OneDrive/Escritorio/migracion/csv_marketing/dim_campania.csv")

dim_campania_f=campania.fillna('NA')

# %%
#migracion de dim_campania.csv a BigQuery

errores = client.insert_rows(table, campania.to_dict(orient="records"))

if errores == []:
  print("Se inserto correctamente")
else:
  print("ERROR", errores)
# Out:
# Se inserto correctamente

# %%
#Lectura de dim_canal.csv

canal = pd.read_csv("C:/Users/jcruz/OneDrive/Escritorio/migracion/csv_marketing/dim_canal.csv")

dim_canal_f=canal.fillna('NA')

# %%
# Conexión a la dataset y obtención de la tabla dim_canal
client = bigquery.Client(project='civil-being-452701-p9')
dataset = client.dataset('marketingdmc_db')
table_tp = dataset.table('dim_canal')
table = client.get_table(table_tp)

# %%
#migracion de dim_canal.csv a BigQuery

errores = client.insert_rows(table, canal.to_dict(orient="records"))

if errores == []:
  print("Se inserto correctamente")
else:
  print("ERROR", errores)
# Out:
# Se inserto correctamente

# %%
#Lectura de dim_dispositivo.csv

dispositivo = pd.read_csv("C:/Users/jcruz/OneDrive/Escritorio/migracion/csv_marketing/dim_dispositivo.csv")

dim_dispositivo_f=dispositivo.fillna('NA')

# %%
print(dispositivo)
# Out:
#    dispositivo_id tipo_dispositivo sistema_operativo
# 0               1            Móvil           Android
# 1               2            Móvil               iOS
# 2               3          Desktop           Windows
# 3               4          Desktop             macOS
# 4               5           Tablet           Android

# %%
# Conexión a la dataset y obtención de la tabla dim_dispositivo
client = bigquery.Client(project='civil-being-452701-p9')
dataset = client.dataset('marketingdmc_db')
table_tp = dataset.table('dim_dispositivo')
table = client.get_table(table_tp)

# %%
#migracion de dim_dispositivo.csv a BigQuery

errores = client.insert_rows(table, dim_dispositivo_f.to_dict(orient="records"))

if errores == []:
  print("Se inserto correctamente")
else:
  print("ERROR", errores)
# Out:
# Se inserto correctamente

# %%
#Lectura de dim_producto.csv

producto = pd.read_csv("C:/Users/jcruz/OneDrive/Escritorio/migracion/csv_marketing/dim_producto.csv")

dim_producto_f=producto.fillna('NA')

# %%
#print de producto
print(producto)
# Out:
#    product_id                nombre_producto  categoria  precio_unitario
# 0           1       Bootcamp de Data Science   Bootcamp           1150.0
# 1           2      Bootcamp de Data Engineer   Bootcamp           1135.0
# 2           3     Bootcamp de Data Analytics   Bootcamp           1156.0
# 3           4      Curso de Machine Learning      Curso            450.0
# 4           5                Curso de Python      Curso            600.0
# 5           6      Curso de Machine Learning      Curso            650.0
# 6           7    Diplomado en Data Analytics  Diplomado           3000.0
# 7           8  Diplomado en Data Engineering  Diplomado           3300.0
# 8           9      Diplomado en Data Science  Diplomado           3500.0

# %%
# Conexión a la dataset y obtención de la tabla dim_dispositivo
client = bigquery.Client(project='civil-being-452701-p9')
dataset = client.dataset('marketingdmc_db')
table_tp = dataset.table('dim_producto')
table = client.get_table(table_tp)

# %%
#migracion de dim_producto.csv a BigQuery


errores = client.insert_rows(table, producto.to_dict(orient="records"))

if errores == []:
  print("Se inserto correctamente")
else:
  print("ERROR", errores)
# Out:
# Se inserto correctamente

# %%
#Lectura de dim_tiempo.csv

tiempo = pd.read_csv("C:/Users/jcruz/OneDrive/Escritorio/migracion/csv_marketing/dim_tiempo.csv")
tiempo_f=tiempo.fillna('NA')

# %%
print(tiempo)
# Out:
#      tiempo_id       fecha  dia  mes   año  trimestre  semana
# 0            1  26/07/2024   26    7  2024          3      30
# 1            2  03/01/2025    3    1  2025          1       1
# 2            3  01/04/2025    1    4  2025          2      13
# 3            4  22/06/2024   22    6  2024          2      25
# 4            5  05/01/2025    5    1  2025          1       1
# ..         ...         ...  ...  ...   ...        ...     ...
# 234        235  11/07/2024   11    7  2024          3      28
# 235        236  19/01/2025   19    1  2025          1       4
# 236        237  20/12/2024   20   12  2024          4      51
# 237        238  31/03/2025   31    3  2025          1      14
# 238        239  21/02/2025   21    2  2025          1       9
#
# [239 rows x 7 columns]

# %%
# Conexión a la dataset y obtención de la tabla dim_dispositivo
client = bigquery.Client(project='civil-being-452701-p9')
dataset = client.dataset('marketingdmc_db')
table_tp = dataset.table('dim_tiempo')
table = client.get_table(table_tp)

# %%
errores = client.insert_rows(table, tiempo.to_dict(orient="records"))

if errores == []:
  print("Se inserto correctamente")
else:
  print("ERROR", errores)
# Out:
# Se inserto correctamente

# %%
#Lectura de fact_interaction.csv

interaccion = pd.read_csv("C:/Users/jcruz/OneDrive/Escritorio/migracion/csv_marketing/fact_interaction.csv")
tiempo_f=interaccion.fillna('NA')

# %%
print(interaccion)
# Out:
#      interaction_id  cliente_id  canal_id  product_id  campaign_id  \
# 0                 1         487         5           7           12
# 1                 2         256         8           2            5
# 2                 3         112         3           9           14
# 3                 4         398         1           4            7
# 4                 5          45        10           6            3
# ..              ...         ...       ...         ...          ...
# 295             296         110        10           2            5
# 296             297         383         4           6           10
# 297             298         256         9           4            4
# 298             299          50         6           7           14
# 299             300         410         1           9            7
#
#      dispositivo_id  region_id  tiempo_id  clics  conversiones  \
# 0                 3          2        187      3             1
# ...

# %%
# Conexión a la dataset y obtención de la tabla dim_dispositivo
client = bigquery.Client(project='civil-being-452701-p9')
dataset = client.dataset('marketingdmc_db')
table_tp = dataset.table('fact_interaction')
table = client.get_table(table_tp)

# %%
errores = client.insert_rows(table, interaccion.to_dict(orient="records"))

if errores == []:
  print("Se inserto correctamente")
else:
  print("ERROR", errores)
# Out:
# Se inserto correctamente
